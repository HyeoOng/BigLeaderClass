# %%
# riss.kr 에서 특정 키워드로 논문 / 학술 자료 검색하기
#Step 1. 필요한 모듈을 로딩합니다                  
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
# import chromedriver_autoinstaller as ca
import pandas as pd 
import time 

#Step 2. 사용자에게 검색 관련 정보들을 입력 받고 3. 파일 이름 정하기
query_txt ='빅데이터'
ft_name = "c:\\Users\\Hyewon\\BigLeader\\Crawler\\day3\\riss.txt"
fc_name = "c:\\Users\\Hyewon\\BigLeader\\Crawler\\day3\\riss.csv"
fx_name = "c:\\Users\\Hyewon\\BigLeader\\Crawler\\day3\\riss.xls"
collect_cnt = 50

#Step 4. 크롬 드라이버 설정 및 웹 페이지 열기
driver = webdriver.Chrome()
driver.get('https://www.riss.kr/')

# 팝업창 닫기
main = driver.window_handles
for handle in main:
    if handle != main[0]:
        driver.switch_to.window(handle)
        driver.close()

driver.switch_to.window(main[0])
driver.maximize_window()

time.sleep(2)

#Step 5. 자동으로 검색어 입력 후 6 학위논문 클릭
driver.find_element(By.ID,'query').send_keys(query_txt+ '\n')
driver.find_element(By.LINK_TEXT,'학위논문').click()
time.sleep(2)

#Step 7.Beautiful Soup 로 본문 내용만 추출하기
# soup_1 = BeautifulSoup(driver.page_source, 'html.parser')
# content_1 = soup_1.find('div','srchResultListW').find_all('li')

# for i in content_1 :
#     # print(i.get_text())
#     print(i.get_text().strip())
#     print("**********")

# %%
#Step 8. 총 검색 건수를 보여주고 수집할 건수 입력받기
import math
soup_1 = BeautifulSoup(driver.page_source, 'html.parser')
total_cnt = soup_1.find('div','searchBox pd').find('span','num').get_text()
print('키워드 %s (으)로  %s 건 검색' %(query_txt,total_cnt))
collect_page_cnt = math.ceil(collect_cnt / 10)
# Out:
# 키워드 빅데이터 (으)로  5,870 건 검색

# %%
#Step 9. 각 항목별로 데이터를 추출하여 리스트에 저장하기
no2 = [ ]        #번호 저장
title2 = [ ]     #논문제목 저장
writer2 = [ ]    #논문저자 저장
org2 = [ ]       #소속기관 저장
no = 1

for a in range(1, collect_page_cnt + 1) :
    
    soup_2 = BeautifulSoup(driver.page_source, 'html.parser', from_encoding='utf-8')
    content_2 = soup_2.find('div','srchResultListW').find_all('li')
    
    for b in content_2 : 
        #1. 논문제목 있을 경우만
        try :
            title = b.find('p','title').text
        except :
            continue
        else :
            f = open(ft_name, 'a' , encoding="UTF-8")
            
            print('1.번호:',no)
            no2.append(no)
            f.write('\n'+'1.번호:' + str(no))

            print('2.논문제목:',title)
            title2.append(title)
            f.write('\n' + '2.논문제목:' + title)
            
            writer = b.find('span','writer').get_text()
            print('3.저자:',writer)
            writer2.append(writer)
            f.write('\n' + '3.저자:' + writer)

            org = b.find('span','assigned').get_text()
            print('4.소속기관:' , org)
            org2.append(org)
            f.write('\n' + '4.소속기관:' + org + '\n')
            
            f.close( )
            
            no += 1
            print("\n")
            
            if no > collect_cnt :
                break

            time.sleep(2)        # 페이지 변경 전 1초 대기 

    a += 1 
    b = '{}'.format(a)
    # print(a)
    # print(b)

    try :
        driver.find_element(By.LINK_TEXT ,b).click()
        time.sleep(2) 
    except :
        driver.find_element(By.LINK_TEXT('다음 페이지로')).click()
        time.sleep(2)
        
print("요청하신 작업이 모두 완료되었습니다")
# Out:
# c:\Users\Hyewon\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# 1.번호: 1
# 2.논문제목: 동형암호를 이용한 개인정보 등 빅데이터의 범죄분석 활용방안 연구
# 3.저자: 정대희
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 2
# 2.논문제목: 빅데이터를 활용한 대학구조개혁 평가의 키워드 및 토픽 분석
# 3.저자: 김지은
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 3
# 2.논문제목: 조직, 개인 그리고 경영품질 관점에서 기업의 빅데이터 활용의도에 영향을 미치는 핵심요인에 관한 연구
# 3.저자: 신수행
# 4.소속기관: 전남대학교
#
#
# 1.번호: 4
# 2.논문제목: 빅데이터 분석의 사용이 은행 CRM 가치 창출에 미치는 영향 : 고객 상호관계 관점으로
# 3.저자: 박성수
# 4.소속기관: 성균관대학교 경영전문대학원
#
#
# 1.번호: 5
# 2.논문제목: 빅데이터 분석 사업의 정보시스템 감리에 대한 연구
# 3.저자: 박성남
# 4.소속기관: 건국대학교 정보통신대학원
#
#
# 1.번호: 6
# 2.논문제목: 빅데이터 활용 탐구 수업의 설계 효과 : 빅데이터 활용 역량과 학습만족도를 중심으로
# 3.저자: 윤한나
# 4.소속기관: 한국교원대학교 교육대학원
#
#
# 1.번호: 7
# 2.논문제목: IPA기법을 활용한 제조분야의 빅데이터 수용도 분석 : IT 분야 제조 A社 중심
# 3.저자: 주혁
# 4.소속기관: 성균관대학교 일반대학원
#
#
# 1.번호: 8
# 2.논문제목: 기후변화 정책 의사결정 지원을 위한 빅데이터 분석
# 3.저자: 정예림
# 4.소속기관: 부산대학교
#
#
# 1.번호: 9
# 2.논문제목: 사회과학의 텍스트로서 빅데이터
# 3.저자: 정준석
# 4.소속기관: 경기대학교 정치전문대학원
#
#
# 1.번호: 10
# 2.논문제목: 빅데이터를 이용한 부산항신항 ITT 효율적인 운영방안에 관한 연구
# 3.저자: 백용주
# 4.소속기관: 한국해양대학교 해양금융물류대학원
#
#
# 1.번호: 11
# 2.논문제목: 음식관광 빅데이터를 이용한 관광목적지 브랜드 개성에 관한 연구: 방한 중국인 관광객을 중심으로
# 3.저자: 연진
# 4.소속기관: 세종대학교 대학원
#
#
# 1.번호: 12
# 2.논문제목: 빅데이터 기반의 자금세탁방지 시스템 연구
# 3.저자: 김상완
# 4.소속기관: 건국대학교 정보통신대학원
#
#
# 1.번호: 13
# 2.논문제목: 빅데이터 환경에서의 개인정보 활용에 대한 소비자인식
# 3.저자: 김인혜
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 14
# 2.논문제목: 빅데이터 기반의 생체신호 분석 사례 및 연구
# 3.저자: 박요셉
# 4.소속기관: 인제대학교 일반대학원
#
#
# 1.번호: 15
# 2.논문제목: 빅데이터를 활용한 도시관광 경쟁력 분석 및 데이터 신뢰성 검정 연구
# 3.저자: 이광용
# 4.소속기관: 전남대학교대학원
#
#
# 1.번호: 16
# 2.논문제목: 빅데이터를 통한 다이어트 실태 조사 및 분석
# 3.저자: 정은진
# 4.소속기관: 동덕여자대학교
#
#
# 1.번호: 17
# 2.논문제목: 빅 데이터 품질에 미치는 요인에 대한 이론적 연구
# 3.저자: 이민영
# 4.소속기관: 한국교통대학교 글로벌융합대학원
#
#
# 1.번호: 18
# 2.논문제목: 다차원 분석기법을 통한 빅데이터 분야 특허 가치 평가
# 3.저자: 노승윤
# 4.소속기관: 충북대학교
#
#
# 1.번호: 19
# 2.논문제목: 빅데이터 활용에 있어서의 개인정보 보호법제에 관한 연구
# 3.저자: 김효정
# 4.소속기관: 동아대학교 대학원
#
#
# 1.번호: 20
# 2.논문제목: 빅데이터 산업의 활성화에 따른 개인정보 보호에 관한 연구
# 3.저자: 차상휘
# 4.소속기관: 전북대학교
#
#
# 1.번호: 21
# 2.논문제목: 빅데이터 플랫폼 활용 사회과 수업이 초등학생의 교과 지식과  교과 흥미에 미치는 영향
# 3.저자: 정자연
# 4.소속기관: 서울교육대학교 교육전문대학원
#
#
# 1.번호: 22
# 2.논문제목: 빅데이터 기술환경에서 정보의 이용에 따른 침해판단방법론
# 3.저자: 고수윤
# 4.소속기관: 강원대학교 대학원
#
#
# 1.번호: 23
# 2.논문제목: SNS빅데이터를 활용한 디지털사이니지 영상콘텐츠 디자인 연구 : 디지털사이니지 매거진TV를 중심으로
# 3.저자: 이진우
# 4.소속기관: 홍익대학교 영상대학원
#
#
# 1.번호: 24
# 2.논문제목: 빅데이터의 정치적 유용성 : 미국과 한국의 대통령선거 캠페인 분석
# 3.저자: 동성혜
# 4.소속기관: 경기대학교 정치전문대학원
#
#
# 1.번호: 25
# 2.논문제목: 빅데이터를 활용한 제조공정 결함 예측에 관한 연구
# 3.저자: 쉬징징
# 4.소속기관: 한세대학교
#
#
# 1.번호: 26
# 2.논문제목: 빅데이터를 통한 바이오의약품의 시장 점유율 분석과 추정에 관한 연구
# 3.저자: 봉기태
# 4.소속기관: 성균관대학교 일반대학원
#
#
# 1.번호: 27
# 2.논문제목: 빅데이터 분석을 활용한 스포츠산업 서비스화 방안에 관한 연구
# 3.저자: 최재석
# 4.소속기관: 忠南大學校 大學院
#
#
# 1.번호: 28
# 2.논문제목: 디지털 잡마켓에서 빅데이터 융합인재 양성을 위한 실무기술역량 연구
# 3.저자: 정재완
# 4.소속기관: 한국기술교육대학교 IT융합과학경영산업대학원
#
#
# 1.번호: 29
# 2.논문제목: 빅데이터 플랫폼을 활용한 公共圖書館 빅데이터 分析 硏究 : 大田한밭圖書館을 中心으로
# 3.저자: 온정미
# 4.소속기관: 한남대학교 대학원
#
#
# 1.번호: 30
# 2.논문제목: 빅데이터 기반의 인적자원개발 교육시스템 아키텍처
# 3.저자: 김용식
# 4.소속기관: 숭실대학교
#
#
# 1.번호: 31
# 2.논문제목: 안전한 개인정보 보호조치를 통한 빅데이터 산업 활성화 방안 : 법 제도·비식별화를 중심으로
# 3.저자: 김동환
# 4.소속기관: 순천향대학교
#
#
# 1.번호: 32
# 2.논문제목: 빅데이터 비즈니스 모델 분석 연구 : 플랫폼 모형을 중심으로
# 3.저자: 술렌한드체렌
# 4.소속기관: 배재대학교 일반대학원
#
#
# 1.번호: 33
# 2.논문제목: 빅데이터 분석을 통한 공기업 이미지 및 주요정책 평가 연구 : 한국토지주택공사(LH) 사례를 중심으로
# 3.저자: 석지연
# 4.소속기관: 고려대학교
#
#
# 1.번호: 34
# 2.논문제목: 조직에서의 빅데이터 시스템 도입을 위한 결정요인에 대한 연구
# 3.저자: 이선우
# 4.소속기관: 성균관대학교 일반대학원
#
#
# 1.번호: 35
# 2.논문제목: 빅데이터 도입이 중국의 제조업 수익성에 미치는 영향
# 3.저자: HAN BO
# 4.소속기관: 부경대학교 대학원
#
#
# 1.번호: 36
# 2.논문제목: 시공간 RDF 빅데이터의 효율적인 분산 병렬 처리 기술
# 3.저자: 신인수
# 4.소속기관: 건국대학교
#
#
# 1.번호: 37
# 2.논문제목: 정보 사회에 있어 재귀적 지식의 생산에 관한 연구 : '빅 데이터" 프레임과 한국 IT 정책지식 재구성 사례를 중심으로
# 3.저자: 손준우
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 38
# 2.논문제목: 빅데이터의 정체성 규명과 의사결정 만족도에 관한 연구와 함의
# 3.저자: 우현종
# 4.소속기관: 韓國外國語大學校 大學院
#
#
# 1.번호: 39
# 2.논문제목: 빅데이터 기반 이상트래픽 분석을 통한 보안관제 강화에 대한 연구
# 3.저자: 이지미
# 4.소속기관: 동국대학교 대학원
#
#
# 1.번호: 40
# 2.논문제목: 빅데이터 교육역량 강화를 위한  H-R도 탐구 프로그램 개발
# 3.저자: 김미림
# 4.소속기관: 한국교원대학교 대학원
#
#
# 1.번호: 41
# 2.논문제목: 빅데이터 기반 사회과 핵심역량 도출과 평가도구 개발 및 검증 : 지리영역을 중심으로
# 3.저자: 박지수
# 4.소속기관: 부산대학교 대학원
#
#
# 1.번호: 42
# 2.논문제목: 빅데이터 속성이 의사결정 만족도와 경영성과에 영향을 미치는 요인
# 3.저자: 이병길
# 4.소속기관: 남서울대학교 대학원
#
#
# 1.번호: 43
# 2.논문제목: 빅데이터를 활용한 방재관련 시민인식 및 전문가인식의 비교 분석
# 3.저자: 김선홍
# 4.소속기관: 서울시립대학교 일반대학원
#
#
# 1.번호: 44
# 2.논문제목: 빅데이터를 활용한 밀키트 추천 앱 설계 및 구현
# 3.저자: 정선미
# 4.소속기관: 광운대학교 대학원
#
#
# 1.번호: 45
# 2.논문제목: 유동인구 빅데이터의 효율적 활용 방안에 관한 연구 : C통신사 사례를 중심으로
# 3.저자: 권용민
# 4.소속기관: 목포대학교 경영행정대학원
#
#
# 1.번호: 46
# 2.논문제목: 빅데이터의 보호 및 이용을 위한 법제 연구 : 지식재산권법과 개인정보보호법을 중심으로
# 3.저자: 최종모
# 4.소속기관: 중앙대학교 대학원
#
#
# 1.번호: 47
# 2.논문제목: 빅데이터 분석을 활용한 국가 자살예방사업의 효율성에 관한 연구
# 3.저자: 민이슬
# 4.소속기관: 성균관대학교 일반대학원
#
#
# 1.번호: 48
# 2.논문제목: 기업의 빅데이터 활성화에 따른 개인정보 문제점에 관한 연구
# 3.저자: 홍상진
# 4.소속기관: 동국대학교
#
#
# 1.번호: 49
# 2.논문제목: 빅데이터를 활용한 패션디자인 감성분석 연구 : 텍스트마이닝과 의미연결망 분석을 중심으로
# 3.저자: 안효선
# 4.소속기관: 이화여자대학교 대학원
#
#
# 1.번호: 50
# 2.논문제목: 빅데이터를 활용한 공연예술분야에서의 해외 사례 연구
# 3.저자: 최아리
# 4.소속기관: 이화여자대학교 공연예술대학원
#
#
# 요청하신 작업이 모두 완료되었습니다

# %%
#Step 9. 각 항목별로 데이터를 추출하여 리스트에 저장하기
no2 = [ ]        #번호 저장
title2 = [ ]     #논문제목 저장
writer2 = [ ]    #논문저자 저장
org2 = [ ]       #소속기관 저장
no = 1

for a in range(1, collect_page_cnt + 1) :
    
    soup_2 = BeautifulSoup(driver.page_source, 'html.parser')
    content_2 = soup_2.find('div','srchResultListW').find_all('li')
    
    for b in content_2 : 
        #1. 논문제목 있을 경우만
        try :
            title = b.find('p','title').get_text()
        except :
            continue
        else :
            f = open(ft_name, 'a' , encoding="UTF-8")
            
            print('1.번호:',no)
            no2.append(no)
            f.write('\n'+'1.번호:' + str(no))

            print('2.논문제목:',title)
            title2.append(title)
            f.write('\n' + '2.논문제목:' + title)
            
            writer = b.find('span','writer').get_text()
            print('3.저자:',writer)
            writer2.append(writer)
            f.write('\n' + '3.저자:' + writer)

            org = b.find('span','assigned').get_text()
            print('4.소속기관:' , org)
            org2.append(org)
            f.write('\n' + '4.소속기관:' + org + '\n')
            
            f.close( )
            
            no += 1
            print("\n")
            
            if no > collect_cnt :
                break

            time.sleep(2)        # 페이지 변경 전 1초 대기 

    a += 1 
    b = '{}'.format(a)
    # print(a)
    # print(b)

    try :
        driver.find_element(By.LINK_TEXT ,b).click() 
    except :
        driver.find_element(By.LINK_TEXT('다음 페이지로')).click()
        
print("요청하신 작업이 모두 완료되었습니다")
# Out:
# 1.번호: 1
# 2.논문제목: 동형암호를 이용한 개인정보 등 빅데이터의 범죄분석 활용방안 연구
# 3.저자: 정대희
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 2
# 2.논문제목: 빅데이터를 활용한 대학구조개혁 평가의 키워드 및 토픽 분석
# 3.저자: 김지은
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 3
# 2.논문제목: 조직, 개인 그리고 경영품질 관점에서 기업의 빅데이터 활용의도에 영향을 미치는 핵심요인에 관한 연구
# 3.저자: 신수행
# 4.소속기관: 전남대학교
#
#
# 1.번호: 4
# 2.논문제목: 빅데이터 분석의 사용이 은행 CRM 가치 창출에 미치는 영향 : 고객 상호관계 관점으로
# 3.저자: 박성수
# 4.소속기관: 성균관대학교 경영전문대학원
#
#
# 1.번호: 5
# 2.논문제목: 빅데이터 분석 사업의 정보시스템 감리에 대한 연구
# 3.저자: 박성남
# 4.소속기관: 건국대학교 정보통신대학원
#
#
# 1.번호: 6
# 2.논문제목: 빅데이터 활용 탐구 수업의 설계 효과 : 빅데이터 활용 역량과 학습만족도를 중심으로
# 3.저자: 윤한나
# 4.소속기관: 한국교원대학교 교육대학원
#
#
# 1.번호: 7
# 2.논문제목: IPA기법을 활용한 제조분야의 빅데이터 수용도 분석 : IT 분야 제조 A社 중심
# 3.저자: 주혁
# 4.소속기관: 성균관대학교 일반대학원
#
#
# 1.번호: 8
# 2.논문제목: 기후변화 정책 의사결정 지원을 위한 빅데이터 분석
# 3.저자: 정예림
# 4.소속기관: 부산대학교
#
#
# 1.번호: 9
# 2.논문제목: 사회과학의 텍스트로서 빅데이터
# 3.저자: 정준석
# 4.소속기관: 경기대학교 정치전문대학원
#
#
# 1.번호: 10
# 2.논문제목: 빅데이터를 이용한 부산항신항 ITT 효율적인 운영방안에 관한 연구
# 3.저자: 백용주
# 4.소속기관: 한국해양대학교 해양금융물류대학원
#
#
# 1.번호: 11
# 2.논문제목: 음식관광 빅데이터를 이용한 관광목적지 브랜드 개성에 관한 연구: 방한 중국인 관광객을 중심으로
# 3.저자: 연진
# 4.소속기관: 세종대학교 대학원
#
#
# 1.번호: 12
# 2.논문제목: 빅데이터 기반의 자금세탁방지 시스템 연구
# 3.저자: 김상완
# 4.소속기관: 건국대학교 정보통신대학원
#
#
# 1.번호: 13
# 2.논문제목: 빅데이터 환경에서의 개인정보 활용에 대한 소비자인식
# 3.저자: 김인혜
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 14
# 2.논문제목: 빅데이터 기반의 생체신호 분석 사례 및 연구
# 3.저자: 박요셉
# 4.소속기관: 인제대학교 일반대학원
#
#
# 1.번호: 15
# 2.논문제목: 빅데이터를 활용한 도시관광 경쟁력 분석 및 데이터 신뢰성 검정 연구
# 3.저자: 이광용
# 4.소속기관: 전남대학교대학원
#
#
# 요청하신 작업이 모두 완료되었습니다

# %%
# Step 10. 수집된 데이터를 xls와 csv 형태로 저장하기
df = pd.DataFrame()
df['번호']=no2
df['제목']=pd.Series(title2)
df['저자']=pd.Series(writer2)
df['소속(발행)기관']=pd.Series(org2)

print(df)

# xls 형태로 저장하기
# df.to_excel(fx_name,index=False, encoding="utf-8" , engine='openpyxl')

# # csv 형태로 저장하기
# df.to_csv(fc_name,index=False, encoding="utf-8-sig")

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
# Out:
#     번호                                                 제목   저자  \
# 0    1    빅데이터 플랫폼 활용 사회과 수업이 초등학생의 교과 지식과  교과 흥미에 미치는 영향  정자연
# 1    2                     빅데이터 기술환경에서 정보의 이용에 따른 침해판단방법론  고수윤
# 2    3  SNS빅데이터를 활용한 디지털사이니지 영상콘텐츠 디자인 연구 : 디지털사이니지 매거...  이진우
# 3    4               빅데이터의 정치적 유용성 : 미국과 한국의 대통령선거 캠페인 분석  동성혜
# 4    5                        빅데이터를 활용한 제조공정 결함 예측에 관한 연구  쉬징징
# 5    6              빅데이터를 통한 바이오의약품의 시장 점유율 분석과 추정에 관한 연구  봉기태
# 6    7                  빅데이터 분석을 활용한 스포츠산업 서비스화 방안에 관한 연구  최재석
# 7    8               디지털 잡마켓에서 빅데이터 융합인재 양성을 위한 실무기술역량 연구  정재완
# 8    9     빅데이터 플랫폼을 활용한 公共圖書館 빅데이터 分析 硏究 : 大田한밭圖書館을 中心으로  온정미
# 9   10                         빅데이터 기반의 인적자원개발 교육시스템 아키텍처  김용식
# 10  11  음식관광 빅데이터를 이용한 관광목적지 브랜드 개성에 관한 연구: 방한 중국인 관광객...   연진
# 11  12                             빅데이터 기반의 자금세탁방지 시스템 연구  김상완
# 12  13                       빅데이터 환경에서의 개인정보 활용에 대한 소비자인식  김인혜
# 13  14                           빅데이터 기반의 생체신호 분석 사례 및 연구  박요셉
# 14  15              빅데이터를 활용한 도시관광 경쟁력 분석 및 데이터 신뢰성 검정 연구  이광용
# 15  16                           빅데이터를 통한 다이어트 실태 조사 및 분석  정은진
# 16  17                        빅 데이터 품질에 미치는 요인에 대한 이론적 연구  이민영
# 17  18                      다차원 분석기법을 통한 빅데이터 분야 특허 가치 평가  노승윤
# 18  19                     빅데이터 활용에 있어서의 개인정보 보호법제에 관한 연구  김효정
# 19  20                    빅데이터 산업의 활성화에 따른 개인정보 보호에 관한 연구  차상휘
#
#                    소속(발행)기관
# 0           서울교육대학교 교육전문대학원
# 1                 강원대학교 대학원
# 2               홍익대학교 영상대학원
# 3             경기대학교 정치전문대학원
# 4                     한세대학교
# 5              성균관대학교 일반대학원
# 6                 忠南大學校 大學院
# 7   한국기술교육대학교 IT융합과학경영산업대학원
# 8                 한남대학교 대학원
# 9                     숭실대학교
# 10                세종대학교 대학원
# 11            건국대학교 정보통신대학원
# 12                서울대학교 대학원
# 13              인제대학교 일반대학원
# 14                 전남대학교대학원
# 15                  동덕여자대학교
# 16         한국교통대학교 글로벌융합대학원
# 17                    충북대학교
# 18                동아대학교 대학원
# 19                    전북대학교
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
